# %%
import csv
from pathlib import Path

# %%
clip_dir = "/Users/hungcucu/Documents/usth/computer_vision/Tennis ball dataset/Dataset/game1/Clip1"
clip_dir = Path(clip_dir)
label_csv = clip_dir / "Label.csv"
# Out:
# 'Clip1'

# %%
with open(label_csv, 'r') as f:
    reader = csv.DictReader(f)

# %%
dataset_dir = "/Users/hungcucu/Documents/usth/computer_vision/Tennis ball dataset/Dataset"
clips =[]
dataset_dir = Path(dataset_dir)

for label_csv in dataset_dir.rglob("Label.csv"):
    clips.append(label_csv.parent)

# %%
(sorted(clips))
# Out:
# [PosixPath('/Users/hungcucu/Documents/usth/computer_vision/Tennis ball dataset/Dataset/game1/Clip1'),
#  PosixPath('/Users/hungcucu/Documents/usth/computer_vision/Tennis ball dataset/Dataset/game1/Clip10'),
#  PosixPath('/Users/hungcucu/Documents/usth/computer_vision/Tennis ball dataset/Dataset/game1/Clip11'),
#  PosixPath('/Users/hungcucu/Documents/usth/computer_vision/Tennis ball dataset/Dataset/game1/Clip12'),
#  PosixPath('/Users/hungcucu/Documents/usth/computer_vision/Tennis ball dataset/Dataset/game1/Clip13'),
#  PosixPath('/Users/hungcucu/Documents/usth/computer_vision/Tennis ball dataset/Dataset/game1/Clip2'),
#  PosixPath('/Users/hungcucu/Documents/usth/computer_vision/Tennis ball dataset/Dataset/game1/Clip3'),
#  PosixPath('/Users/hungcucu/Documents/usth/computer_vision/Tennis ball dataset/Dataset/game1/Clip4'),
#  PosixPath('/Users/hungcucu/Documents/usth/computer_vision/Tennis ball dataset/Dataset/game1/Clip5'),
# ...

# %%
images_all = Path("/Users/hungcucu/Documents/usth/computer_vision/tennis_analysis/yolo_dataset/images/all")
print((images_all.glob("*.jpg")))
# Out:
# <generator object Path.glob at 0x106f7dcf0>

# %%
image_path = Path('/Users/hungcucu/Documents/usth/computer_vision/Tennis ball dataset/Dataset/game1/Clip1/0000.jpg')
image_path.stem + ".txt"
# Out:
# '0000.txt'

# %%
image_path.stat().st_size
# Out:
# 112207
